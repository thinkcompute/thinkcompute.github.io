# %% [markdown]
# Using Pandas read the CSV file `notebook/01-publications.csv` and create a dataframe with an internal identifier which follows the format `P{NUMBER}` and includes the doi, title, and the publication year as attributes of each publications, also include the `publication venue` to relate to the elements inside the dataframe venues, defined as follow:
# ```
# df_venues = pd.DataFrame({
#     "id": ["9780470291092", "1367-5931"],
#     "editor_name": ["Tom the Editor", "James the Editor"]
# })
# ```

# %%
from sqlite3 import connect
from pandas import read_csv, Series

df_publications = read_csv("../notebook/01-publications.csv", 
                        keep_default_na=False,
                        dtype={
                            "doi": "string",
                            "title": "string",
                            "publication year": "int",
                            "publication venue": "string",
                        })

# Create a new column with internal identifiers for each publication
publication_internal_id = []
for idx, row in publications.iterrows():
    publication_internal_id.append("P" + str(idx))
df_publications.insert(0, "internalId", Series(publication_internal_id, dtype="string"))


df_venues = pd.DataFrame({
    "id": ["9780470291092", "1367-5931"],
    "editor_name": ["Tom the Editor", "James the Editor"]
})

df_joined = merge(df_publications, df_venues, left_on="publication venue", right_on="id")

publications
# Out:
#   internalId                            doi  \
# 0         P0                10.1002/cfg.304
# 1         P1  10.1016/s1367-5931(02)00332-0
# 2         P2     10.1002/9780470291092.ch20
#
#                                                title  publication year  \
# 0  Development of Computational Tools for the Inf...              2003
# 1  In vitro selection as a powerful tool for the ...              2002
# 2  Mechanisms of Toughening in Ceramic Matrix Com...              1981
#
#   publication venue             type issue volume
# 0         1531-6912  journal article     4      4
# 1         1367-5931  journal article     3      6
# 2     9780470291092     book chapter
